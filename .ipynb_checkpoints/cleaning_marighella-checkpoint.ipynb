# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import nltk.corpus

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Avell G1745
# [nltk_data]     MAX\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
# Out:
# ['.ipynb_checkpoints', 'cleaning_marighella.ipynb', 'data_direita_semrt_todos.csv']

# %%
data = pd.read_csv('data_direita_semrt_todos.csv')
data
# Out:
#          tweet id         username  \
# 0    1.097856e+18    depheliolopes
# 1    1.097856e+18    depheliolopes
# 2    1.217505e+18  CarlaZambelli38
# 3    1.097821e+18  CarlaZambelli38
# 4    1.097214e+18  CarlaZambelli38
# ..            ...              ...
# 223  1.038418e+18         fasalles
# 224  1.462214e+18          pauloap
# 225  1.454881e+18          pauloap
# 226  1.197307e+18          pauloap
# 227  1.097949e+18          pauloap
#
#                                                                                                                                                                                                         text
# 0    Carlos Marighella tinha viés comunista e foi o criador da ALN, \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar. \n#DepHelioLopes #MinhaCorÉoBrasi...
# 1    Carlos Marighella tinha viés comunista e foi o criador da ALN, \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar. \n#DepHelioLopes #MinhaCorÉoBrasi...
# 2    O filme do Marighella não vem para o Brasil porque é MUITO RUIM, não por conta de suposta “censura”.\n\nJá o filme estrelado por Wagner Moura - Sergio - é uma baita produção e com certeza irei ass...
# 3                                                                                                 DITADURA: Em represália ao filme de Wagner Moura, Lava Jato persegue até o motorista do Marighella!\n\n😂😂😂
# 4    Você vai assistir ao filme do Marighella?\n\nNão interessa: você pagou pelo ingresso do mesmo jeito.\n\nEm 2013, ainda no governo Dilma, o filme exaltando o assassino foi autorizado a captar R$ 10...
# ..                                                                                                                                                                                                       ...
# 223                                                                           Boa lembrança o Marighella, assassino herói do outros não é igual ao meu herói assassino. Incoerência! https://t.co/AIthwKW3aj
# 224                                                                                                                                                           @bertaze_r Qual filme, Marighella? Vc foi ver?
# 225                                               Primeiro que o Marighella nem negro era, parem de falar merda\n\nE ataque quem fazia era esse terrorista que hoje tão homenageando https://t.co/TTfy7TrUSO
# 226  Quer reclamar da homenagem ao Pinochet? OK, sem problemas\n\nMas então, não seja um hipócrita do caralho e reclame também quando homenageiam Marighella, Revolução Russa, Fidel Castro, Coreia do No...
# 227                                                       Excelente video do @bernardopkuster explicando quem foi o assassino Carlos Marighella\n\nassistam e compartilhem o link\n\nhttps://t.co/g1IVisJBHc
#
# [228 rows x 3 columns]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import re
data['text'] = data['text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
data.head()
# Out:
#        tweet id         username  \
# 0  1.097856e+18    depheliolopes
# 1  1.097856e+18    depheliolopes
# 2  1.217505e+18  CarlaZambelli38
# 3  1.097821e+18  CarlaZambelli38
# 4  1.097214e+18  CarlaZambelli38
#
#                                                                                                                                                                                                       text
# 0   Carlos Marighella tinha viés comunista e foi o criador da ALN, \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar. \n#DepHelioLopes #MinhaCorÉoBrasil
# 1   Carlos Marighella tinha viés comunista e foi o criador da ALN, \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar. \n#DepHelioLopes #MinhaCorÉoBrasil
# 2  O filme do Marighella não vem para o Brasil porque é MUITO RUIM, não por conta de suposta “censura”.\n\nJá o filme estrelado por Wagner Moura - Sergio - é uma baita produção e com certeza irei ass...
# 3                                                                                               DITADURA: Em represália ao filme de Wagner Moura, Lava Jato persegue até o motorista do Marighella!\n\n😂😂😂
# 4  Você vai assistir ao filme do Marighella?\n\nNão interessa: você pagou pelo ingresso do mesmo jeito.\n\nEm 2013, ainda no governo Dilma, o filme exaltando o assassino foi autorizado a captar R$ 10...

# %%
def remove_punctuation(txt):
    txt_nopunct = ''.join([c for c in txt if c not in string.punctuation])
    return txt_nopunct

# %%
data['text'] = data['text'].apply(lambda x: remove_punctuation(x))
data.head()
# Out:
#        tweet id         username  \
# 0  1.097856e+18    depheliolopes
# 1  1.097856e+18    depheliolopes
# 2  1.217505e+18  CarlaZambelli38
# 3  1.097821e+18  CarlaZambelli38
# 4  1.097214e+18  CarlaZambelli38
#
#                                                                                                                                                                                                       text
# 0       Carlos Marighella tinha viés comunista e foi o criador da ALN \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar \nDepHelioLopes MinhaCorÉoBrasil
# 1       Carlos Marighella tinha viés comunista e foi o criador da ALN \nação libertadora nacional que agia por meio de atentados \nterrorista na época do regime militar \nDepHelioLopes MinhaCorÉoBrasil
# 2  O filme do Marighella não vem para o Brasil porque é MUITO RUIM não por conta de suposta “censura”\n\nJá o filme estrelado por Wagner Moura  Sergio  é uma baita produção e com certeza irei assisti...
# 3                                                                                                  DITADURA Em represália ao filme de Wagner Moura Lava Jato persegue até o motorista do Marighella\n\n😂😂😂
# 4  Você vai assistir ao filme do Marighella\n\nNão interessa você pagou pelo ingresso do mesmo jeito\n\nEm 2013 ainda no governo Dilma o filme exaltando o assassino foi autorizado a captar R 10285835...

# %%
import re

def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

data['text'] = data['text'].apply(lambda x: tokenize(x.lower()))

data.head()
# Out:
#        tweet id         username  \
# 0  1.097856e+18    depheliolopes
# 1  1.097856e+18    depheliolopes
# 2  1.217505e+18  CarlaZambelli38
# 3  1.097821e+18  CarlaZambelli38
# 4  1.097214e+18  CarlaZambelli38
#
#                                                                                                                                                                                                       text
# 0  [carlos, marighella, tinha, viés, comunista, e, foi, o, criador, da, aln, ação, libertadora, nacional, que, agia, por, meio, de, atentados, terrorista, na, época, do, regime, militar, depheliolope...
# 1  [carlos, marighella, tinha, viés, comunista, e, foi, o, criador, da, aln, ação, libertadora, nacional, que, agia, por, meio, de, atentados, terrorista, na, época, do, regime, militar, depheliolope...
# 2  [o, filme, do, marighella, não, vem, para, o, brasil, porque, é, muito, ruim, não, por, conta, de, suposta, censura, já, o, filme, estrelado, por, wagner, moura, sergio, é, uma, baita, produção, e...
# 3                                                                                      [ditadura, em, represália, ao, filme, de, wagner, moura, lava, jato, persegue, até, o, motorista, do, marighella, ]
# 4  [você, vai, assistir, ao, filme, do, marighella, não, interessa, você, pagou, pelo, ingresso, do, mesmo, jeito, em, 2013, ainda, no, governo, dilma, o, filme, exaltando, o, assassino, foi, autoriz...

# %%
def remove_stopwords(txt_tokenized):
    txt_clean = [word for word in txt_tokenized if word not in stopwords]
    return txt_clean

data['text'] = data['text'].apply(lambda x: remove_stopwords(x))
data.head()
# Out:
#        tweet id         username  \
# 0  1.097856e+18    depheliolopes
# 1  1.097856e+18    depheliolopes
# 2  1.217505e+18  CarlaZambelli38
# 3  1.097821e+18  CarlaZambelli38
# 4  1.097214e+18  CarlaZambelli38
#
#                                                                                                                                                                                                       text
# 0                           [carlos, marighella, viés, comunista, criador, aln, ação, libertadora, nacional, agia, meio, atentados, terrorista, época, regime, militar, depheliolopes, minhacoréobrasil, ]
# 1                           [carlos, marighella, viés, comunista, criador, aln, ação, libertadora, nacional, agia, meio, atentados, terrorista, época, regime, militar, depheliolopes, minhacoréobrasil, ]
# 2  [filme, marighella, vem, brasil, porque, ruim, conta, suposta, censura, filme, estrelado, wagner, moura, sergio, baita, produção, certeza, irei, assistir, nada, contra, boa, arte, contra, mentiras...
# 3                                                                                                              [ditadura, represália, filme, wagner, moura, lava, jato, persegue, motorista, marighella, ]
# 4   [vai, assistir, filme, marighella, interessa, pagou, ingresso, jeito, 2013, ainda, governo, dilma, filme, exaltando, assassino, autorizado, captar, r, 1028583535, dinheiro, iria, cofres, públicos, ]

# %%
data.to_csv('direita_cleaned.csv', index = False)

# %%
data_saved_file = pd.read_csv('direita_cleaned.csv')
data_saved_file
# Out:
#          tweet id         username  \
# 0    1.097856e+18    depheliolopes
# 1    1.097856e+18    depheliolopes
# 2    1.217505e+18  CarlaZambelli38
# 3    1.097821e+18  CarlaZambelli38
# 4    1.097214e+18  CarlaZambelli38
# ..            ...              ...
# 223  1.038418e+18         fasalles
# 224  1.462214e+18          pauloap
# 225  1.454881e+18          pauloap
# 226  1.197307e+18          pauloap
# 227  1.097949e+18          pauloap
#
#                                                                                                                                                                                                         text
# 0    ['carlos', 'marighella', 'viés', 'comunista', 'criador', 'aln', 'ação', 'libertadora', 'nacional', 'agia', 'meio', 'atentados', 'terrorista', 'época', 'regime', 'militar', 'depheliolopes', 'minhac...
# 1    ['carlos', 'marighella', 'viés', 'comunista', 'criador', 'aln', 'ação', 'libertadora', 'nacional', 'agia', 'meio', 'atentados', 'terrorista', 'época', 'regime', 'militar', 'depheliolopes', 'minhac...
# 2    ['filme', 'marighella', 'vem', 'brasil', 'porque', 'ruim', 'conta', 'suposta', 'censura', 'filme', 'estrelado', 'wagner', 'moura', 'sergio', 'baita', 'produção', 'certeza', 'irei', 'assistir', 'na...
# 3                                                                                          ['ditadura', 'represália', 'filme', 'wagner', 'moura', 'lava', 'jato', 'persegue', 'motorista', 'marighella', '']
# 4    ['vai', 'assistir', 'filme', 'marighella', 'interessa', 'pagou', 'ingresso', 'jeito', '2013', 'ainda', 'governo', 'dilma', 'filme', 'exaltando', 'assassino', 'autorizado', 'captar', 'r', '10285835...
# ..                                                                                                                                                                                                       ...
# 223                                                                                     ['boa', 'lembrança', 'marighella', 'assassino', 'herói', 'outros', 'igual', 'herói', 'assassino', 'incoerência', '']
# 224                                                                                                                                                         ['bertazer', 'filme', 'marighella', 'vc', 'ver']
# 225                                                                       ['primeiro', 'marighella', 'negro', 'parem', 'falar', 'merda', 'ataque', 'fazia', 'terrorista', 'hoje', 'tão', 'homenageando', '']
# 226  ['quer', 'reclamar', 'homenagem', 'pinochet', 'ok', 'problemas', 'então', 'hipócrita', 'caralho', 'reclame', 'homenageiam', 'marighella', 'revolução', 'russa', 'fidel', 'castro', 'coreia', 'norte'...
# 227                                                                     ['excelente', 'video', 'bernardopkuster', 'explicando', 'assassino', 'carlos', 'marighella', 'assistam', 'compartilhem', 'link', '']
#
# [228 rows x 3 columns]
